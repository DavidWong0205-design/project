# %%
import yfinance as yf
import pandas as pd
import requests
from io import StringIO

# 抓取 S&P 500 股票清單
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
headers = {"User-Agent": "Mozilla/5.0"}  
response = requests.get(url, headers=headers, timeout=20)
response.raise_for_status()
html = response.text

tables = pd.read_html(StringIO(html))
sp500 = tables[0]
symbols = sp500['Symbol'].tolist()



data = []

for symbol in symbols:  # 只抓前 10 個股票
    ticker = yf.Ticker(symbol)   # ✅ 單一股票
    info = ticker.info           # 這裡才有 info
    
    data.append({
        "symbol": symbol,
        "company_name": info.get("longName"),
        "sector": info.get("sector"),
        "industry": info.get("industry")
    })

df = pd.DataFrame(data)

from sqlalchemy import create_engine


engine = create_engine("postgresql+psycopg2://postgres:admin1234@localhost:5432/bootcamp2512")


df.to_sql("stock_info", engine, if_exists="replace", index=False)
# Out:
# 503
